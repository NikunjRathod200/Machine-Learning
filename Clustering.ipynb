# %% [markdown]
# <a href="https://colab.research.google.com/github/NikunjRathod200/Machine-Learning/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_blobs
X,y =make_blobs(n_samples=1000, centers=5, n_features=4, random_state=2529)

# %%
X.shape
# Out:
# (1000, 4)

# %%
y.shape
# Out:
# (1000,)

# %%
y
# Out:
# array([0, 2, 3, 3, 2, 4, 0, 4, 4, 2, 2, 4, 3, 2, 2, 0, 4, 3, 0, 1, 4, 1,
#        3, 1, 1, 0, 3, 0, 3, 2, 3, 0, 2, 2, 3, 3, 1, 0, 0, 1, 4, 4, 4, 0,
#        1, 2, 0, 0, 2, 3, 2, 4, 4, 0, 1, 0, 1, 2, 3, 4, 3, 4, 0, 3, 0, 0,
#        2, 0, 3, 1, 0, 1, 1, 2, 4, 0, 0, 2, 4, 4, 2, 2, 3, 0, 3, 1, 4, 3,
#        1, 0, 0, 4, 0, 1, 0, 1, 4, 2, 3, 2, 1, 0, 2, 4, 2, 0, 3, 1, 2, 0,
#        3, 2, 3, 1, 3, 2, 4, 0, 3, 0, 2, 4, 0, 4, 2, 3, 4, 1, 4, 3, 4, 3,
#        1, 3, 2, 2, 2, 3, 4, 3, 2, 0, 2, 1, 2, 2, 2, 2, 0, 2, 3, 0, 1, 4,
#        0, 1, 0, 1, 3, 4, 2, 4, 2, 2, 2, 0, 2, 0, 2, 3, 4, 1, 0, 4, 4, 0,
#        2, 3, 2, 0, 0, 1, 3, 3, 1, 0, 0, 0, 1, 4, 3, 0, 2, 0, 2, 2, 3, 4,
#        0, 3, 4, 3, 2, 1, 1, 4, 0, 2, 0, 0, 0, 0, 3, 0, 2, 0, 2, 1, 0, 0,
#        1, 1, 2, 3, 1, 1, 4, 3, 0, 0, 1, 3, 0, 0, 1, 4, 2, 0, 4, 4, 0, 4,
#        1, 1, 2, 4, 4, 4, 1, 4, 0, 0, 0, 1, 1, 1, 1, 4, 4, 4, 3, 1, 4, 1,
#        4, 1, 2, 2, 0, 3, 4, 1, 3, 2, 4, 0, 3, 0, 3, 2, 0, 1, 0, 3, 4, 4,
# ...

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
sns.pairplot(pd.DataFrame(X))

# %%
from sklearn.cluster import KMeans

# %%
km=KMeans()

# %%
kmeans= KMeans(n_clusters=5, init='k-means++', n_init=10, max_iter=300 ,random_state=2529)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=2529)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.77263901, -8.07362334, -9.83609784,  2.13160046],
#        [-2.50663079, -1.44083693,  1.61115321, -3.18120903],
#        [ 8.29057689,  2.42629516,  4.97809236,  5.72640769],
#        [ 5.75892936, -4.83336429, -4.31754193,  1.14143554],
#        [-4.01484683, -5.15014505,  0.24562627,  3.04672031]])

# %%
X
# Out:
# array([[-4.93557215, -6.11135445,  0.45392589,  1.70858804],
#        [-2.55674336, -0.99613454,  1.21511189, -3.83110206],
#        [ 5.90894448, -5.16474848, -4.25183516,  3.61126602],
#        ...,
#        [-4.15998427, -7.0036478 , -0.77229637,  3.41352471],
#        [-3.99254802, -4.47062661, -1.0252071 ,  3.38244921],
#        [ 0.61450157, -8.67094948, -9.92944894,  2.20309641]])

# %%
kmeans.labels_
# Out:
# array([4, 1, 3, 3, 1, 0, 4, 0, 0, 1, 1, 0, 3, 1, 1, 4, 0, 3, 4, 2, 0, 2,
#        3, 2, 2, 4, 3, 4, 3, 1, 3, 4, 1, 1, 3, 3, 2, 4, 4, 2, 0, 0, 0, 4,
#        2, 1, 4, 4, 1, 3, 1, 0, 0, 4, 2, 4, 2, 1, 3, 0, 3, 0, 4, 3, 4, 4,
#        1, 4, 3, 2, 4, 2, 2, 1, 0, 4, 4, 1, 0, 0, 1, 1, 3, 4, 3, 2, 0, 3,
#        2, 4, 4, 0, 4, 2, 4, 2, 0, 1, 3, 1, 2, 4, 1, 0, 1, 4, 3, 2, 1, 4,
#        3, 1, 3, 2, 3, 1, 0, 4, 3, 4, 1, 0, 4, 0, 1, 3, 0, 2, 0, 3, 0, 3,
#        2, 3, 1, 1, 1, 3, 0, 3, 1, 4, 1, 2, 1, 1, 1, 1, 4, 1, 3, 4, 2, 0,
#        4, 2, 4, 2, 3, 0, 1, 0, 1, 1, 1, 4, 1, 4, 1, 3, 0, 2, 4, 0, 0, 4,
#        1, 3, 1, 4, 4, 2, 3, 3, 2, 4, 4, 4, 2, 0, 3, 4, 1, 4, 1, 1, 3, 0,
#        4, 3, 0, 3, 1, 2, 2, 0, 4, 1, 4, 4, 4, 4, 3, 4, 1, 4, 1, 2, 4, 4,
#        2, 2, 1, 3, 2, 2, 0, 3, 4, 4, 2, 3, 4, 4, 2, 0, 1, 4, 0, 0, 4, 0,
#        2, 2, 1, 0, 0, 0, 2, 0, 4, 4, 4, 2, 2, 2, 2, 0, 0, 0, 3, 2, 0, 2,
#        0, 2, 1, 1, 4, 3, 0, 2, 3, 1, 0, 4, 3, 4, 3, 1, 4, 2, 4, 3, 0, 0,
# ...
